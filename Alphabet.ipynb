# %%
char = input("Enter the alphabet(in upper case) you want: ")
if char == "A":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print("",p*3)
        elif i == 2:
            print(p * 1, " ", p * 1)
        elif i == 3:
            print(p * 5)
        elif i == 4:
            print(p * 1, " ", p * 1)
        elif i == 5:
            print(p * 1, " ", p * 1)
        i += 1
elif char=="B":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print(p * 5)
        elif i == 2:
            print(p * 1, "  ", p * 1)
        elif i == 3:
            print(p * 5)
        elif i == 4:
            print(p * 1, "  ", p * 1)
        elif i == 5:
            print(p * 5)
        i += 1

elif char=="C":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print("", p * 4)
        elif i == 2:
            print(p * 1)
        elif i == 3:
            print(p * 1, " " * 4)
        elif i == 4:
            print(p * 1)
        elif i == 5:
            print("", p * 4)
        i += 1
elif char == "D":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print(p * 5)
        elif i == 2:
            print(p * 1, "  ", p * 1)
        elif i == 3:
            print(p * 1, " " * 2, p * 1)
        elif i == 4:
            print(p * 1, "  ", p * 1)
        elif i == 5:
            print(p * 5)
        i += 1
elif char == "E":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print(p * 5)
        elif i == 2:
            print(p * 1, " " * 4)
        elif i == 3:
            print(p * 4)
        elif i == 4:
            print(p * 1, " " * 4)
        elif i == 5:
            print(p * 5)
        i += 1
elif char=="F":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print(p * 5)
        elif i == 2:
            print(p * 1, " " * 4)
        elif i == 3:
            print(p * 4)
        elif i == 4:
            print(p * 1, " " * 4)
        elif i == 5:
            print(p * 1)
        i += 1
elif char == "G":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print("  ", p * 5)
        elif i == 2:
            print("", p * 1, "    ", p * 1)
        elif i == 3:
            print(p * 1, " " * 4)
        elif i == 4:
            print("", p * 1, "   ", p * 3)
        elif i == 5:
            print("  ", p * 4, "", p)
        i += 1
elif char == "H":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print(p * 1, " ", p * 1)
        elif i == 2:
            print(p * 1, " ", p * 1)
        elif i == 3:
            print(p * 5)
        elif i == 4:
            print(p * 1, " ", p * 1)
        elif i == 5:
            print(p * 1, " ", p * 1)
        i += 1
elif char == "I":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print(p * 5)
        elif i == 2:
            print(" ", p * 1)
        elif i == 3:
            print(" ", p * 1)
        elif i == 4:
            print(" ", p * 1)
        elif i == 5:
            print(p * 5)
        i += 1
elif char == "J":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print(p * 6)
        elif i == 2:
            print("   ", p * 1)
        elif i == 3:
            print("   ", p * 1)
        elif i == 4:
            print(p, " ", p * 1)
        elif i == 5:
            print("", p, p)
        i += 1

elif char == "K":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print(p, " ", p)
        elif i == 2:
            print(p, "", p)
        elif i == 3:
            print(p, p)
        elif i == 4:
            print(p, "", p)
        elif i == 5:
            print(p, " ", p)
        i += 1
elif char == "L":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print(p)
        elif i == 2:
            print(p)
        elif i == 3:
            print(p)
        elif i == 4:
            print(p)
        elif i == 5:
            print(p * 5)
        i += 1
elif char == "M":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print(p, " " * 5, p)
        elif i == 2:
            print(p, p, " ", p, p)
        elif i == 3:
            print(p, " ", p, " ", p)
        elif i == 4:
            print(p, " " * 5, p)
        elif i == 5:
            print(p, " " * 5, p)
        i += 1
elif char == "N":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print(p, " " * 5, p)
        elif i == 2:
            print(p, p, " " * 3, p)
        elif i == 3:
            print(p, " ", p, " ", p)
        elif i == 4:
            print(p, " " * 3, p, p)
        elif i == 5:
            print(p, " " * 5, p)
        i += 1
elif char == "O":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print("", p * 5)
        elif i == 2:
            print(p * 1, " " * 3, p * 1)
        elif i == 3:
            print(p * 1, " " * 3, p * 1)
        elif i == 4:
            print(p * 1, " " * 3, p * 1)
        elif i == 5:
            print("", p * 5)
        i += 1
elif char == "P":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print(p * 5)
        elif i == 2:
            print(p * 1, "  ", p * 1)
        elif i == 3:
            print(p * 5)
        elif i == 4:
            print(p * 1)
        elif i == 5:
            print(p)
        i += 1
elif char == "Q":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print("", p * 5)
        elif i == 2:
            print(p * 1, " " * 3, p * 1)
        elif i == 3:
            print(p * 1, p, " ", p * 1)
        elif i == 4:
            print(p * 1, " ", p, p)
        elif i == 5:
            print("", p * 4, p, p)
        i += 1
elif char == "R":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print(p * 5)
        elif i == 2:
            print(p * 1, "  ", p * 1)
        elif i == 3:
            print(p * 5)
        elif i == 4:
            print(p, "" * 3, p)
        elif i == 5:
            print(p, " " * 2, p)
        i += 1
elif char == "S":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print("", p * 5)
        elif i == 2:
            print(p * 1, " ")
        elif i == 3:
            print("", p * 5)
        elif i == 4:
            print(" " * 5, p * 1)
        elif i == 5:
            print(p * 5)
        i += 1
elif char == "T":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print(p * 5)
        elif i == 2:
            print(" ", p * 1)
        elif i == 3:
            print(" ", p * 1)
        elif i == 4:
            print(" ", p * 1)
        elif i == 5:
            print(" ", p)
        i += 1
elif char == "U":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print(p, " " * 3, p)
        elif i == 2:
            print(p * 1, " " * 3, p * 1)
        elif i == 3:
            print(p * 1, " " * 3, p * 1)
        elif i == 4:
            print(p * 1, " " * 3, p * 1)
        elif i == 5:
            print("", p * 5)
        i += 1
elif char == "V":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print(p, " " * 3, p)
        elif i == 2:
            print(p * 1, " " * 3, p * 1)
        elif i == 3:
            print(p * 1, " " * 3, p * 1)
        elif i == 4:
            print("", p, " ", p)
        elif i == 5:
            print(" " * 2, p)
        i += 1
elif char == "W":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print(p, " " * 5, p)
        elif i == 2:
            print(p, " " * 5, p)
        elif i == 3:
            print(p, " ", p, " ", p)
        elif i == 4:

            print(p, p, " ", p, p)
        elif i == 5:
            print(p, " " * 5, p)
        i += 1
elif char == "X":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print(p, " " * 5, p)
        elif i == 2:
            print(" ", p, " ", p)
        elif i == 3:
            print(" " * 3, p)
        elif i == 4:
            print(" ", p, " ", p)
        elif i == 5:
            print(p, " " * 5, p)
        i += 1
elif char == "Y":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print(p, " ", p)
        elif i == 2:
            print("", p, p)
        elif i == 3:
            print(" ", p)
        elif i == 4:
            print(" ", p)
        elif i == 5:
            print(" ", p)
        i += 1
elif char == "Z":
    i = 1
    p = "*"
    while i <= 5:
        if i == 1:
            print(p * 6)
        elif i == 2:
            print(" " * 4, p)
        elif i == 3:
            print(" " * 2, p)
        elif i == 4:
            print(p)
        elif i == 5:
            print(p * 6)
        i += 1
else:
    print("Your input isn't an alphabet")
# Out:
# Enter the alphabet(in upper case) you want: A
#  ***
# *   *
# *****
# *   *
# *   *
